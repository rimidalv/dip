# %%
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec
import random as rd
# %matplotlib inline

# %%
import cv2
import numpy as np

# %%
def load_dict(filename):
    with open(filename) as f:
        data = f.readlines()
        data = [d[:98].strip() for d in data]
        
#         a=  [text_to_labels(d) for d in data]
#         print("data len:", str(len(data)))
#         print(a)
    return data

# %%
# dict_words = load_dict("./data/words_dict.txt")
# dict_words = rd.sample(dict_words, 5000)
# bank_name = load_dict("./data/banksName.txt")
# bank_bik = load_dict("./data/banksBik.txt")
# bank_acc = load_dict("./data/banksCorrAcc.txt")
# receiver_name = load_dict("./data/firmsNames.txt")
# other_words = ["Получатель", "Банк получателя", "БИК", "Сч. №", "ИНН", "КПП"]*100

# %%
# samples = bank_name + bank_bik + bank_acc + receiver_name + other_words + dict_words

# %%
# words = rd.sample(samples, 1000)

# %%
# words[:1000]

# %%
# with open("print_words.txt", "w") as f:
#     f.write("\n".join(words))

# %%
words = load_dict("./print_words.txt")

# %%
words[:1000]
# Out:
# ['кусака',
#  'ФИЛИАЛ "САМАРСКИЙ" АО "ОТП БАНК" г. САМАРА',
#  '30101810600000000743',
#  '30101810300000000448',
#  'буерачный',
#  'ультрафильтрация',
#  'фехтование',
#  'силуэтность',
#  '040012002',
#  'Сч. №',
#  'потребовать',
#  'бездомник',
#  '30101810980730000948',
#  'во всю мощь',
#  'ускакнуть',
#  '044525560',
#  'потяжелеть',
#  'Сч. №',
#  'очеса',
#  'свадьбище',
#  '041403001',
#  'извод',
#  'Банк получателя',
#  'огрести',
#  'зарешечивать',
#  'АРТ-БЛЕСК',
#  '30101810045250000210',
#  'АО АКБ "ЦЕНТРОКРЕДИТ" г. МОСКВА',
#  'Гарнитура, ООО',
#  '30101810400000000978',
#  'Сч. №',
#  'станкостроитель',
#  '044525544',
#  'рабовладелица',
#  'тахеометрия',
#  '30101810100000000922',
#  'уширяться',
#  'Банк получателя',
#  'поварня',
#  'настрачивание',
#  '30101810900000000713',
#  'понервничать',
#  'Центр оценки авто',
#  'проповедующийся',
#  'Спецтехника ГрАЗ, ТД, ООО, представительство в г. Москве',
#  'рекамбио',
#  'ООО КБ "ЕВРОАЗИАТСКИЙ ИНВЕСТИЦИОННЫЙ БАНК" г. МОСКВА',
#  '30101810900000000746',
#  '044525094',
#  'АО "СОЦИНВЕСТБАНК" г. УФА',
#  'СИМФЕРОПОЛЬСКИЙ ФИЛИАЛ АБ "РОССИЯ" г. СИМФЕРОПОЛЬ',
#  'перекраденный',
#  'ООО "ИТ МААС"',
#  'ООО "Нэт Бай Нэт Холдинг"',
#  '043209740',
#  'бодаться',
#  'БИК',
#  '045306000',
#  'скарифицироваться',
#  'Safe-Tec',
#  'киновидеоматериалы',
#  'Банк получателя',
#  '044959746',
#  'тарантул',
#  'Экоакрил',
#  'заделка',
#  'вылечивание',
#  '044705615',
#  'теленовелла',
#  '048717000',
#  'ЕКАТЕРИНБУРГСКИЙ ФИЛИАЛ ТКБ БАНК ПАО г. ЕКАТЕРИНБУРГ',
#  'пропустить',
#  'кверулянтство',
#  '041708001',
#  'полуплоскость',
#  '046711001',
#  'остроумный',
#  'ООО "Внуковский ЖБИ"',
#  '30101810900000000839',
#  'Диатех-ЭМ, ООО',
#  'напутственный',
#  'телепрограмма',
#  '30101810000000000846',
#  'Клио-Софт, ООО',
#  'ркацители',
#  '30101810100000000835',
#  'приведшийся',
#  'щитник',
#  'азотометр',
#  '"КУРСКИЙ" ФИЛИАЛ ПАО БАНК ЗЕНИТ г. КУРСК',
#  'подшлифовывать',
#  'перетрушиваться',
#  '045004708',
#  '046015081',
#  '30101810845250000517',
#  'лишать',
#  'МОСКОВСКИЙ ФИЛИАЛ АО "БКС БАНК" г. МОСКВА',
#  'ФИЛИАЛ "САНКТ-ПЕТЕРБУРГСКИЙ" АО "ОТП БАНК" г. САНКТ-ПЕТЕРБУРГ',
#  '"Макетная мастерская ГУП "МОСАРХИНФОРМ"',
#  'побуждать',
#  'КБ "НМБ" ООО г. МОСКВА',
#  '30101810245250000298',
#  'сплутовать',
#  'зашпандоривать',
#  'оперетта',
#  'спецконтингент',
#  'ОТДЕЛЕНИЕ ЯРОСЛАВЛЬ г. ЯРОСЛАВЛЬ',
#  'гипоцентрический',
#  'завистница',
#  'АО "БАНК ОРЕНБУРГ" г. ОРЕНБУРГ',
#  '30101810500000000641',
#  'ИНГУШСКИЙ РФ АО "РОССЕЛЬХОЗБАНК" г. НАЗРАНЬ',
#  'повыходить',
#  'РОСТОВСКИЙ РФ АО "РОССЕЛЬХОЗБАНК" г. РОСТОВ-НА-ДОНУ',
#  'колонуть',
#  'пневмоконструкция',
#  '048880002',
#  '040702754',
#  '30101810900000000910',
#  'зашпаклёвывать',
#  'вскакивание',
#  'отрывание',
#  'присоединяться',
#  '048073928',
#  '040407627',
#  'Сч. №',
#  '"СДМ-БАНК" (ПАО) г. МОСКВА',
#  '043601875',
#  'РКЦ БРАТСК г. БРАТСК',
#  'заиндевелый',
#  'ООО ЛЕДОХОДЫ',
#  'отчерчивать',
#  'отреветь',
#  'альянс',
#  '30103810000000000201',
#  'террасёр',
#  'БИК',
#  'ХАБАРОВСКИЙ ФИЛИАЛ НКО "ИНКАХРАН" (АО) г. ХАБАРОВСК',
#  'пятнить',
#  '043304711',
#  'Арчнефть, геологоразведочная компания, ООО',
#  'ИНН',
#  'разнополюсный',
#  'Общество с ограниченной ответственностью "Унопринт"',
#  'РКЦ СЕВЕРОБАЙКАЛЬСК г. СЕВЕРОБАЙКАЛЬСК',
#  'праздниться',
#  '"СЕВЕРНЫЙ НАРОДНЫЙ БАНК" (ПАО) Ф-Л В Г.МОСКВА г. МОСКВА',
#  'словоизвержение',
#  'Центр Развития Лидерства',
#  'Национальная противопожарная страховая компания, ООО',
#  'спиленный',
#  'многоэтажье',
#  'призадуматься',
#  'ПУ БАНКА РОССИИ ЦИОЛКОВСКОЕ г. ЗНАМЕНСК',
#  '042748701',
#  '041424000',
#  'Мимоза Ф, компания, ООО',
#  '30101810445250000412',
#  '30101810500000000653',
#  'ввёрстывать',
#  'денатурировать',
#  'гулливый',
#  '044030882',
#  '043469714',
#  'перешлифованный',
#  'ФИЛИАЛ "ВОЛЖСКИЙ" ПАО "СКБ-БАНК" г. ВОЛЖСКИЙ',
#  'мингрелка',
#  'Частная школа Классическое образование',
#  'ПУ БАНКА РОССИИ N 43192',
#  'хлыщ',
#  'неоконфуцианец',
#  'Ф-Л БАНКА ГПБ (АО) "ЮЖНЫЙ" г. КРАСНОДАР',
#  'в расход',
#  'Ораторика',
#  'пьезогеофон',
#  '040401000',
#  'Глобус-Телеком, ЗАО',
#  'ФГУП "Московская фабрика ортопедической обуви" Федерального агентства по здравоохранению и социаль',
#  'аппендикулярный',
#  'ФИЛИАЛ "МОСКОВСКИЙ" АБ "АСПЕКТ" (АО) г. МОСКВА',
#  'КРАСНОДАРСКИЙ ФИЛИАЛ ПАО РОСБАНК г. КРАСНОДАР',
#  'надуться',
#  'бдение',
#  '044525196',
#  '042520769',
#  '30101810400000000551',
#  'КБ "СТРОЙЛЕСБАНК" (ООО) г. ТЮМЕНЬ',
#  'ФИЛИАЛ КАЛИНИНГРАДСКИЙ БАНКА ВТБ (ПАО) г. КАЛИНИНГРАД',
#  'заставание',
#  'Сч. №',
#  'нерудный',
#  'примитив',
#  'перекувырнуться',
#  'Д-р Вайгерт сервис, ООО',
#  '30101810045250000456',
#  'БИК',
#  'секретаришка',
#  '30101810500000000925',
#  'КПП',
#  'ФИЛИАЛ ВОЛОГОДСКИЙ БАНКА ВТБ (ПАО) г. ВОЛОГДА',
#  'ЧЕЛЯБИНСКИЙ РФ АО "РОССЕЛЬХОЗБАНК" г. ЧЕЛЯБИНСК',
#  '045004816',
#  'деблокироваться',
#  'камфарный',
#  'выручить',
#  'ЕвроПолис, СК, ООО',
#  'фототеодолит',
#  'обществовед',
#  'рыхлый',
#  'пескорой',
#  'ПУ БАНКА РОССИИ N 52481 п. ХАНКАЛА',
#  '042809909',
#  'доторговать',
#  '044030812',
#  'скромность',
#  '042809903',
#  '047003755',
#  'бессцепочный',
#  'споровый',
#  '044525637',
#  'околотиться',
#  'приточенный',
#  'предводительница',
#  'Получатель',
#  'ФИЛИАЛ АО "ГЕНБАНК" В Г. МОСКВЕ г. МОСКВА',
#  'маслозаправочный',
#  'Алегро, кадровое агентство, ООО',
#  '046015080',
#  'Среднеафганские горы',
#  '30101810760150000052',
#  'интерпеллировать',
#  'УРАЛЬСКИЙ ФИЛИАЛ АО "БАНК ИНТЕЗА" г. ЕКАТЕРИНБУРГ',
#  'аллопластика',
#  'ЯРОСЛАВСКИЙ ФИЛИАЛ ТКБ БАНК ПАО г. ЯРОСЛАВЛЬ',
#  'отжатие',
#  'АКБ "НРБАНК" (АО) г. МОСКВА',
#  '048142001',
#  '044525696',
#  'подписание',
#  'Оргтехсервис, ООО',
#  '047501711',
#  '040349830',
#  '044030833',
#  'точка',
#  'компонентный',
#  'кучковаться',
#  'диппаспорт',
#  'моргать',
#  'Webincom',
#  'фасеточный',
#  '30101810507080000772',
#  'Общество с ограниченной ответственностью "Автономия МКС"',
#  'склонять',
#  '30101810800000000708',
#  'метровагон',
#  'тузлук',
#  'ПУ БАНКА РОССИИ N 64106',
#  'черноватый',
#  'ВОЛОГОДСКОЕ ОТДЕЛЕНИЕ N8638 ПАО СБЕРБАНК г. ВОЛОГДА',
#  'ООО "Дельфин Спорт"',
#  'отшкуренный',
#  'стандартизировать',
#  '041403783',
#  'ООО "УНИФОНДБАНК" г. МОСКВА',
#  'грабительница',
#  '043510607',
#  'АЗИЯ-ИНВЕСТ БАНК (АО) г. МОСКВА',
#  '046015913',
#  'Ф-Л БАНКА "ТРАСТ" (ПАО) В Г.ЧЕРЕПОВЕЦ г. ЧЕРЕПОВЕЦ',
#  'плазмоциты',
#  'ФПАО "ДАЛЬНЕВОСТОЧНЫЙ БАНК" "ХАБАРОВСКИЙ" г. ХАБАРОВСК',
#  '044525132',
#  'Совдепия',
#  'Большое Домодедово',
#  'Получатель',
#  'Получатель',
#  '044782002',
#  'Сч. №',
#  'чтец-декламатор',
#  'СЕВЕРО-ЗАПАДНЫЙ БАНК ПАО СБЕРБАНК г. САНКТ-ПЕТЕРБУРГ',
#  'волокно',
#  '30101810940300000751',
#  'запениться',
#  'цитоплазма',
#  'черничник',
#  'сосцы',
#  'расхулённый',
#  '30101810300000000600',
#  'Медицинский центр "Панацея"',
#  '30101810400000000705',
#  '043469564',
#  'заполаскивание',
#  'Аскин и КО, ООО',
#  '042980002',
#  '30101810000000000804',
#  '042282751',
#  '045004867',
#  '044525156',
#  'роль',
#  'писарский',
#  '30101810000000000705',
#  '040813608',
#  'детант',
#  '044030851',
#  'процокать',
#  'Институт корпоративного развития',
#  '040508000',
#  'ИНН',
#  'принципиальничать',
#  'октаэдр',
#  'Делаем подарки',
#  'Ф-Л БАНКА ГПБ (АО) "ЗАПАДНО-УРАЛЬСКИЙ" г. ПЕРМЬ',
#  'ИНН',
#  'двусторонний',
#  'подседельный',
#  'офлюсовываться',
#  '30101810060150000066',
#  '040407699',
#  '044525666',
#  'ЗАО "НПК Эллирон"',
#  'ледышка',
#  '041806701',
#  '044030810',
#  'обсевать',
#  '30127810945250000051',
#  'КПП',
#  'рентгенотехник',
#  'газопереработчик',
#  'в дым',
#  'разгром',
#  'вымораживание',
#  '046015961',
#  'шрифт-касса',
#  'КПП',
#  'ООО КБ "КОНФИДЭНС БАНК" г. КОСТРОМА',
#  'РКЦ АНАПА г. АНАПА',
#  'ООО "ЧАЙНАСЕЛЬХОЗБАНК" г. МОСКВА',
#  'дополоскаться',
#  'допинг-проба',
#  'Группа компаний "ТЕПЛОЦЕНТРСТРОЙ"',
#  'Сч. №',
#  'КПП',
#  'САНКТ-ПЕТЕРБУРГСКИЙ ФИЛИАЛ ООО "ХКФ БАНК" г. САНКТ-ПЕТЕРБУРГ',
#  'перерезываться',
#  'ООО КБ "СИНКО-БАНК" г. МОСКВА',
#  'архимиллионер',
#  'западный',
#  '047003001',
#  '044525122',
#  'аннексированный',
#  'вдох',
#  'АО "ВЭЛТОН БАНК" г. БЕЛГОРОД',
#  'ковроделие',
#  'фрачный',
#  '30101810900000000745',
#  '30101810900000000703',
#  'Получатель',
#  'беспосадочный',
#  'не за что',
#  'механорецепторы',
#  'Эталон',
#  'юмор',
#  'верховье',
#  'прочесться',
#  '044030751',
#  'Epicor|Scala',
#  'ФИЛИАЛ "ПЕРМСКИЙ" ПАО КБ "УБРИР" г. ПЕРМЬ',
#  'ООО КБ "ГЕФЕСТ" г. КИМРЫ',
#  'Visaprint.ru',
#  'ПУ БАНКА РОССИИ N 67903',
#  '"МУНИЦИПАЛЬНЫЙ КАМЧАТПРОФИТБАНК" (АО) г. ПЕТРОПАВЛОВСК-КАМЧАТСКИЙ',
#  'лактационный',
#  '"КОММЕРЧЕСКИЙ ИНДО БАНК" ООО г. МОСКВА',
#  '042202807',
#  'Успеньев день',
#  'АО КБ "ФОРБАНК" г. МОСКВА',
#  '30101810560150000061',
#  'лаповый',
#  'Интернет магазин нижнего белья ARDI в Москве',
#  '30101810500000000862',
#  'высверливать',
#  'Курсы английского языка «Шестое чувство»',
#  'КПП',
#  'химобработка',
#  '30101810400000000885',
#  'АО КБ "РУБЛЕВ" г. МОСКВА',
#  'Банк получателя',
#  '30101810500000000841',
#  'растраченность',
#  '046311887',
#  'ООО РельсОпт',
#  'галисийцы',
#  'свараджисты',
#  'зачищаться',
#  'КБ "РУССКИЙ ИПОТЕЧНЫЙ БАНК" (ООО) г. МОСКВА',
#  'задрапированный',
#  'АО "ТАТСОЦБАНК" г. КАЗАНЬ',
#  '046359728',
#  'ПУ БАНКА РОССИИ ОКТЯБРЬСКОЕ г. МИРНЫЙ 12',
#  'СТАВРОПОЛЬСКИЙ ФИЛИАЛ ПАО "РГС БАНК" г. СТАВРОПОЛЬ',
#  'контроль',
#  'фаст-фуд',
#  'подбородник',
#  'незакономерность',
#  'распятие',
#  'АО "ГЛОБЭКСБАНК" г. МОСКВА',
#  'Служба доставки еды и пиццы «eda9.ru»',
#  'манифольд',
#  '044030745',
#  '"Alpha-Express"',
#  'смотреться',
#  '043010000',
#  '041501729',
#  'оттачивание',
#  'прощупывать',
#  'АО "НДБАНК" г. МОСКВА',
#  'БИК',
#  'лежать',
#  'сострогать',
#  'поковочный',
#  'Получатель',
#  'мягкокожий',
#  '30101810000000000311',
#  '046577795',
#  'нечерноземье',
#  '044525487',
#  'МОСКОВСКИЙ ФИЛИАЛ ПАО "МЕТКОМБАНК" г. МОСКВА',
#  'Интернет-магазин велосипедов Байксалон',
#  'перетруждать',
#  'АО "БАНК РУССКИЙ СТАНДАРТ" г. МОСКВА',
#  'акантовый',
#  'РКЦ ШАХТЫ г. ШАХТЫ',
#  '046614776',
#  '044525831',
#  'ООО КБ "АКСОНБАНК" г. КОСТРОМА',
#  '049304737',
#  'госпредприятие',
#  'УРАЛЬСКОЕ ГУ БАНКА РОССИИ г. ЕКАТЕРИНБУРГ',
#  'импровизировать',
#  'РКЦ ЕЙСК г. ЕЙСК',
#  'летающий',
#  '046126001',
#  'пролонгироваться',
#  '30101810900000000729',
#  'метаэтнический',
#  '040349781',
#  '047102854',
#  'кукурузоуборочный',
#  'САНКТ-ПЕТЕРБУРГСКИЙ ФИЛИАЛ ТКБ БАНК ПАО г. САНКТ-ПЕТЕРБУРГ',
#  '044030785',
#  '30101810900000000863',
#  'злопыхательный',
#  'кипрегельный',
#  'перезабыть',
#  '30101810200000000700',
#  'домешанный',
#  'Протекшен Сервис, ООО',
#  'УХТИНСКИЙ-ПКБ ФИЛИАЛ ПАО БАНКА "ФК ОТКРЫТИЕ" г. УХТА',
#  'байдарка',
#  'застройка',
#  'гулящий',
#  'лейшмания',
#  'КПП',
#  'контрасигноваться',
#  'нестыковка',
#  'половица',
#  'политонический',
#  '30101810540300000782',
#  'фонарь',
#  'ООО "ЭЛАВиК"',
#  '042007801',
#  'КПП',
#  'АО "СЕВАСТОПОЛЬСКИЙ МОРСКОЙ БАНК" г. СЕВАСТОПОЛЬ',
#  'подполье',
#  'стлать',
#  '046015239',
#  '044525440',
#  'РКЦ КОМСОМОЛЬСК-НА-АМУРЕ г. КОМСОМОЛЬСК-НА-АМУРЕ',
#  'ООО КБ "НЭКЛИС-БАНК" г. МОСКВА',
#  'трещиноватость',
#  'ПАО "АК БАРС" БАНК г. КАЗАНЬ',
#  'преобразователь',
#  'Сч. №',
#  'ФИЛИАЛ АО "БАЙКАЛИНВЕСТБАНК" В Г. МОСКВА г. МОСКВА',
#  'конвейерный',
#  'гражданско-процессуальный',
#  'Сч. №',
#  'Show Project, ООО',
#  'шнапс',
#  '044525416',
#  'конгломерат',
#  '30101810100000000550',
#  'ультразвук',
#  '30101810245250000997',
#  '30101810122020000704',
#  'заузданный',
#  '30101810645250000319',
#  'проиндексированный',
#  'ВитАргос-Россовит, ООО',
#  'примас',
#  '30101810860150000062',
#  'поэкзаменовать',
#  'вкопанный',
#  'пузанок',
#  'Белый Нил',
#  '30101810860150000321',
#  '041403740',
#  'САМАРСКИЙ ФИЛИАЛ ТКБ БАНК ПАО г. САМАРА',
#  '30103810400000000803',
#  'соотечественница',
#  'Нефтехимэкспорт, ООО',
#  'живёшенький',
#  'стратосфера',
#  'депозитарий',
#  'РКЦ БЕЛОРЕЦК г. БЕЛОРЕЦК',
#  'ИНН',
#  'воюющий',
#  'рюмка',
#  'ОМСКИЙ ФИЛИАЛ ПАО АКБ "СВЯЗЬ-БАНК" г. ОМСК',
#  'пролаза',
#  'АО "РАЙФФАЙЗЕНБАНК" г. МОСКВА',
#  '30101810200000000830',
#  '044030702',
#  'клятвопреступница',
#  'парильщица',
#  '30101810545250000273',
#  '30101810600000000749',
#  'воднолыжный',
#  'Printside',
#  'ООО КБ "НЕВАСТРОЙИНВЕСТ" г. САНКТ-ПЕТЕРБУРГ',
#  '30101810145250000754',
#  'АКБ "ЛАНТА-БАНК" (АО) г. МОСКВА',
#  'брюшко',
#  'ИНН',
#  '30101810400000000351',
#  'ООО "АМРА-М"',
#  '044525234',
#  'РКЦ СУРГУТ г. СУРГУТ',
#  'ИНН',
#  'БИК',
#  'чумачество',
#  'Розан Файнэнс, ЗАО',
#  'сродственник',
#  '30101810950040000811',
#  'провертеться',
#  'Солвер',
#  'каллозный',
#  'вымарывание',
#  'РКЦ КОЛОМНА г. КОЛОМНА',
#  '044525717',
#  'АО МС БАНК РУС г. МОСКВА',
#  '045004864',
#  '"БСТ-БАНК" АО г. НОВОКУЗНЕЦК',
#  'наглинка',
#  'путеец',
#  'плеяда',
#  'ООО "Сити Химчистки Прачечные"',
#  'соматотип',
#  '30101810300000000772',
#  'ночёвки',
#  '043207612',
#  'InsolGroup',
#  '30101810445250000836',
#  'сосуля',
#  'накоситься',
#  '044525795',
#  'модельерша',
#  '30101810550040000839',
#  'ФАКБ "РОССИЙСКИЙ КАПИТАЛ" (ПАО) ЧЕЛЯБИНСКИЙ г. ЧЕЛЯБИНСК',
#  '30101810700000000806',
#  'очеркистка',
#  '30101810845250000805',
#  'примеривать',
#  'КЕМЕРОВСКОЕ ОТДЕЛЕНИЕ N8615 ПАО СБЕРБАНК г. КЕМЕРОВО',
#  'Радиопром, ЗАО',
#  'валет',
#  '044525835',
#  '046015761',
#  'умнеть',
#  '30101810800000000710',
#  '30101810860150000075',
#  'ООО "БАСТИОН"',
#  'дерябнуть',
#  'завеса',
#  'Получатель',
#  'Ф-Л "ЕВРОПЕЙСКИЙ" ПАО "БАНК "САНКТ-ПЕТЕРБУРГ" г. КАЛИНИНГРАД',
#  'АО КБ "АССОЦИАЦИЯ" г. НИЖНИЙ НОВГОРОД',
#  'рецепт',
#  'Интрон Плюс, ООО',
#  'конструкционный',
#  'ФИЛИАЛ N 2351 БАНКА ВТБ (ПАО) г. КРАСНОДАР',
#  'хмелевод',
#  'ФАКБ "АБСОЛЮТ БАНК" (ПАО) В Г. НОВОСИБИРСКЕ г. НОВОСИБИРСК',
#  'НОВОСИБИРСКИЙ ФИЛИАЛ ПАО "МТС-БАНК" г. НОВОСИБИРСК',
#  'ООО "Маршал"',
#  'искрасна-жёлтый',
#  '30101810303490000789',
#  '041708602',
#  'НКО НКЦ (АО) г. МОСКВА',
#  'поразбитый',
#  'низвести',
#  'зооциды',
#  '044525133',
#  'БИК',
#  'БИК',
#  'надурачиться',
#  'Интехцентр, ООО',
#  'рассупонить',
#  'плач',
#  'ФИЛИАЛ N 2754 БАНКА ВТБ (ПАО) г. ХАБАРОВСК',
#  '042406608',
#  'издоить',
#  'рукав',
#  '30101810603490000777',
#  '30101810045250000430',
#  '048327736',
#  'ТУЛЬСКИЙ ФИЛИАЛ АБ "РОССИЯ" г. ТУЛА',
#  'ООО "НПО АДЕМ"',
#  'немузыкант',
#  'ЮЖНОЕ ГУ БАНКА РОССИИ г. КРАСНОДАР',
#  'Tourassist',
#  'КРАСНОДАРСКИЙ Ф БАНКА"ВОЗРОЖДЕНИЕ"(ПАО) г. КРАСНОДАР',
#  'Банк получателя',
#  '30101810500000000708',
#  'крокирование',
#  'НОВОСИБИРСКИЙ РФ АО "РОССЕЛЬХОЗБАНК" г. НОВОСИБИРСК',
#  'ПРИО-ВНЕШТОРГБАНК (ПАО) г. РЯЗАНЬ',
#  'ТУВИНСКИЙ РФ АО "РОССЕЛЬХОЗБАНК" г. КЫЗЫЛ',
#  'БАНК "ТААТТА" АО г. ЯКУТСК',
#  '046577972',
#  'САНКТ-ПЕТЕРБУРГСКИЙ ФИЛИАЛ АО КБ "ИС БАНК" г. САНКТ-ПЕТЕРБУРГ',
#  'бухвостить',
#  'РКЦ ЗЛАТОУСТ г. ЗЛАТОУСТ',
#  'IC Electronics, ООО',
#  '30101810145250000550',
#  'БАНК ИПБ (АО) г. МОСКВА',
#  'настоятельный',
#  'ООО "ОСКОЛБАНК" г. СТАРЫЙ ОСКОЛ',
#  'ООО Аметист, Оптовый интернет-магазин по продаже одежды и обуви',
#  'децентрализованный',
#  '045209885',
#  'Получатель',
#  'китобойный',
#  'копия',
#  'Получатель',
#  'лавабо',
#  '30101810300000000701',
#  'трагедийный',
#  '042202873',
#  '30101810200000000919',
#  'БИК',
#  'кокковидный',
#  'эвфония',
#  'Мауксион Трейд, ТД, ООО',
#  'ВОЛГОГРАДСКИЙ ФИЛИАЛ АБ "РОССИЯ" г. ВОЛГОГРАД',
#  'перекантовать',
#  'Продэкс, ООО',
#  '"INTRADE AS"',
#  'нехотя',
#  'крикуша',
#  'Правда',
#  'ИНН',
#  'ООО "Высотный сервис"',
#  'заплеснуться',
#  'ПАО "ОФК БАНК" г. МОСКВА',
#  '043601878',
#  'микроавтобус',
#  'Паван С. П. А, представительство в г. Москве',
#  '044525595',
#  '30101810800000000805',
#  'Банк получателя',
#  'чешуя',
#  'ПРИВОЛЖСКИЙ ФИЛИАЛ АО КБ "СИТИБАНК" г. НИЖНИЙ НОВГОРОД',
#  '044525257',
#  '047144000',
#  'фа-мажорный',
#  'Avtoservis-chehov',
#  'ИМПРЕССО',
#  '047169000',
#  'преуменьшать',
#  'Ниавек Телеком, ООО',
#  'амёбоидный',
#  '30101810622020000712',
#  'долгоножка',
#  'Русстайл, строительная компания, ООО',
#  'эквилибр',
#  'икание',
#  'подзаработать',
#  'Котофей',
#  'Сч. №',
#  'льнопрядильщица',
#  '30101810100000000834',
#  '044525097',
#  'радиотелескопия',
#  'добриваться',
#  'неосведомлённый',
#  '040583002',
#  'молотильщик',
#  'плетущий',
#  'слюноотделительный',
#  'развороченный',
#  '30101810945250000637',
#  '30101810245250000104',
#  'отставание',
#  'втаптывание',
#  'БАШКОМСНАББАНК (ПАО) г. УФА',
#  '044525805',
#  'бакалавр',
#  'ООО НКО "МУРМАНСКИЙ РАСЧЕТНЫЙ ЦЕНТР" г. МУРМАНСК',
#  'туркменка',
#  '040349536',
#  'Получатель',
#  'АККО-РИЕЛТИ',
#  'доклад',
#  'к чему',
#  'крошево',
#  'КПП',
#  'Сч. №',
#  '30101810700000000886',
#  '30101810400000000873',
#  'Аптека 36,6',
#  'РЯЗАНСКИЙ РФ АО "РОССЕЛЬХОЗБАНК" г. РЯЗАНЬ',
#  'струя',
#  'державник',
#  'осложниться',
#  'скандализовать',
#  'Бюро телекоммуникационных технологий, ООО',
#  'доницеттиевский',
#  'наглаживание',
#  'диагностический',
#  'растачивать',
#  'великолукский',
#  '044525243',
#  '30101810445250000580',
#  'наматрасник',
#  'подвяливаться',
#  '30101810922023601811',
#  '044525236',
#  '043510123',
#  'пришлёпнутый',
#  'микрофильмированный',
#  'лактоны',
#  'Корнета-М, ООО',
#  'ПУ БАНКА РОССИИ ГЕОРГИЕВСКОЕ г. БУДЕННОВСК',
#  'одобренный',
#  'выданье',
#  'Стоматологическая клиника "РигаСтом"',
#  '047888670',
#  'строкомер',
#  '30101810800000000858',
#  'ПУ БАНКА РОССИИ ПРИБРЕЖНОЕ г. ФОКИНО',
#  'ИНН',
#  'побранивать',
#  '30101810900000000880',
#  '30101810300000000765',
#  '"БУМ-БАНК",ООО г. НАЛЬЧИК',
#  'ослышаться',
#  '046711103',
#  'экстероцепция',
#  'страйкер',
#  'вышаривать',
#  'РКЦ БОРОВИЧИ г. БОРОВИЧИ',
#  'манёвренный',
#  'просунутый',
#  'НКО "ПРЕМИУМ" (ООО) г. МОСКВА',
#  'вогнуть',
#  'Сч. №',
#  'ортодоксальный',
#  'Банк получателя',
#  '044030783',
#  'РКЦ КОМСОМОЛЬСКИЙ г. НАБЕРЕЖНЫЕ ЧЕЛНЫ',
#  'ашихара-карате',
#  'поселение',
#  'супостат',
#  'БИК',
#  'клановый',
#  '30101810240300000794',
#  'героико-романтический',
#  'НОУ "Институт Международного Бизнес Образования"',
#  'МОСКОВСКИЙ ФИЛИАЛ ПАО "ЛИПЕЦККОМБАНК" г. МОСКВА',
#  'Студия красоты "Красное Яблоко"',
#  'собачница',
#  'АО "ТЕЛЕКОММЕРЦ БАНК" г. ТУЛА',
#  'граммометр',
#  'подсвист',
#  '042007855',
#  'ФИЛИАЛ БАНКА ВТБ (ПАО) В Г. ПЕТРОЗАВОДСКЕ г. ПЕТРОЗАВОДСК',
#  '30101810100000000788',
#  'пятизвёздочный',
#  'АО "КРЕДИТ ЕВРОПА БАНК" г. МОСКВА',
#  'Команда граффити дизайнеров VIVACITY',
#  'поздневикторианский',
#  'унимать',
#  'перемазать',
#  'ПАО "БЫСТРОБАНК" г. ИЖЕВСК',
#  'где-либо',
#  'завянуть',
#  'малоземельцы',
#  'КИРИШСКИЙ Ф-Л ПАО "БАНК "САНКТ-ПЕТЕРБУРГ" г. КИРИШИ',
#  'ТОЧКА ПАО БАНКА "ФК ОТКРЫТИЕ" г. МОСКВА',
#  'ПАО "ТОМСКПРОМСТРОЙБАНК" г. ТОМСК',
#  'арабистика',
#  'смолевой',
#  '30103810345250000934',
#  'Банк получателя',
#  '046015230',
#  '044525104',
#  'Спектр, ЗАО',
#  '044525121',
#  '30101810300000000606',
#  'закончиться',
#  'Rabiz-Audi',
#  '040813867',
#  'заминаться',
#  '042406807',
#  'шумеро-аккадский',
#  'изобличиться',
#  'FinCIB Company Management Ltd',
#  'ФИЛИАЛ "ЧЕЛЯБИНСКИЙ" АО "ОТП БАНК" г. ЧЕЛЯБИНСК',
#  'Классика, МПО, ООО',
#  'ФИЛИАЛ БАНКА МБСП (АО) В УЛЬЯНОВСКЕ г. УЛЬЯНОВСК',
#  'АО "СИТИ ИНВЕСТ БАНК" г. САНКТ-ПЕТЕРБУРГ',
#  'запихивание',
#  '044080002',
#  'ОТДЕЛЕНИЕ КОСТРОМА г. КОСТРОМА',
#  'ФАКБ "РОССИЙСКИЙ КАПИТАЛ" (ПАО) ХАБАРОВСКИЙ г. ХАБАРОВСК',
#  'Pelco',
#  'сверхсекретность',
#  '043510107',
#  'перешвартовать',
#  'просмолить',
#  'по-лисьи',
#  'изгрызший',
#  'споролистик',
#  'креационист',
#  'переоркестровывать',
#  'казна',
#  '30101810500000000811',
#  'пожароизоляционный',
#  'преюдициальный',
#  'Габсбурги',
#  'Авеста-Фарм, ООО',
#  'Министерство Штемпельной продукции',
#  'кашлевый',
#  'замешаться',
#  'ГлавСнаб макулатура',
#  'параклинический',
#  'ФПАО "ДАЛЬНЕВОСТОЧНЫЙ БАНК" "ИРКУТСКИЙ" г. ИРКУТСК',
#  'мастерица',
#  'Распродажа товаров телемагазина',
#  'ПУ БАНКА РОССИИ МИЧУРИНСКОЕ г. САРАТОВ 63',
#  'Диагностические системы — Столица, ООО',
#  'подсоединить',
#  '044030866',
#  'пристрельный',
#  '047102693',
#  'ИВАНОВСКИЙ РФ АО "РОССЕЛЬХОЗБАНК" г. ИВАНОВО',
#  'варенец',
#  'анфельция',
#  'унывать',
#  'АКБ "ПРОИНВЕСТБАНК" (ПАО) г. ПЕРМЬ',
#  'КБ "НОВОЕ ВРЕМЯ" (ООО) г. МОСКВА',
#  '044525580',
#  'расселение',
#  '30101810445250000166',
#  'ИНН',
#  'акросома',
#  'рассерженный',
#  'МОСКОВСКИЙ ФИЛИАЛ ПАО КБ "ВОСТОЧНЫЙ" г. МОСКВА',
#  'задублированный',
#  'АвиаПромПодшипник, ТД, ООО',
#  'ФЛЕБОЛОГ ЦЕНТРА ФЛЕБОЛОГИИ',
#  'своднический',
#  '044525766',
#  '044525162',
#  'сеанс',
#  'АО КБ "ИВАНОВО" г. ИВАНОВО',
#  'ПУ БАНКА РОССИИ ТАЕЖНОЕ г. КОМСОМОЛЬСК-НА-АМУРЕ 31',
#  'ЕКАТЕРИНБУРГСКИЙ ФИЛИАЛ ПАО "АК БАНК" г. ЕКАТЕРИНБУРГ',
#  'ЯКУТСКИЙ ФИЛИАЛ ПАО АКБ "СВЯЗЬ-БАНК" г. ЯКУТСК',
#  'Пегас',
#  'микрокапсулированный',
#  '30101810100000000748',
#  'Автокомпас, ООО',
#  'обессмысленный',
#  'бордюрчик',
#  'массикот',
#  'ОАО "Фабрика-прачечная № 19"',
#  'плоскокрыший',
#  'задержаться',
#  '046015055',
#  '30101810745250000659',
#  '044525202',
#  '30101810207020000807',
#  'СТ-ПЕТЕРБУРГСКИЙ Ф-Л ПАО "ПРОМСВЯЗЬБАНК" г. САНКТ-ПЕТЕРБУРГ',
#  '043601707',
#  '30101810000000000272',
#  'гидатофиты',
#  'диатремы',
#  'ООО "ИнфоТэк"',
#  '048860001',
#  '30101810845250000067',
#  '30101810150040000763',
#  'замачивать',
#  '044593002',
#  'ИП Шестаков',
#  'аннона',
#  'фут',
#  'ООО "Стэла"',
#  'АО "РУНЭТБАНК" г. МОСКВА',
#  'ПЕНЗЕНСКОЕ ОТДЕЛЕНИЕ N8624 ПАО СБЕРБАНК г. ПЕНЗА',
#  'ООО "СПЕЦСТРОЙБАНК" г. МОСКВА',
#  'СЕВЕРО-ЗАПАДНЫЙ ФИЛИАЛ ПАО "ЗАПСИБКОМБАНК" г. САНКТ-ПЕТЕРБУРГ',
#  'рогоклюв',
#  'ЗАО "Издательское предприятие редакции журнала "Радиотехника"',
#  '30101810145250000288',
#  '044525677',
#  'запоганиваться',
#  '045004760',
#  'ООО "Пролог-Мюзик"',
#  'задаривание',
#  'хиросимец',
#  '30101810000000000813',
#  'таратайка',
#  'зажимание',
#  'упомненный',
#  'кроликовод',
#  'прооппонированный',
#  '040349736',
#  'диккит',
#  'МАГАДАНСКИЙ Ф БАНКА"ВОЗРОЖДЕНИЕ"(ПАО) г. МАГАДАН',
#  '047144964',
#  'Искож-Трейд, ПКФ, ООО',
#  'собеседник',
#  '30101810364010000818',
#  'КПП',
#  'БАНК "РЕСО КРЕДИТ" (АО) г. МОСКВА',
#  'массовик',
#  'заплесневелость',
#  'заавансировать',
#  'приходский',
#  'вздваиваться',
#  '"WashParts" - запчасти для стиральных и посудомоечных машин оптом и в розницу',
#  'АО КБ "НИБ" г. САМАРА',
#  'КУРСКИЙ РФ АО "РОССЕЛЬХОЗБАНК" г. КУРСК',
#  'КПП',
#  'бранивать',
#  'ООО "Компания Нортекс"',
#  '049923001',
#  'пропилитизация',
#  'расковырянный',
#  'вузовский',
#  '040507883',
#  'КУ НКО КРАСНОЯРСКИЙ КРАЕВОЙ РАСЧЕТНЫЙ ЦЕНТР ООО г. КРАСНОЯРСК',
#  '048142711',
#  'псевдогемальный',
#  'выпытанный',
#  'развинченный',
#  'ГК "АГЕНТСТВО ПО СТРАХОВАНИЮ ВКЛАДОВ" г. МОСКВА',
#  'БСконсалтинг (Бизнес Систем консалтинг)',
#  'Александровская слобода',
#  'мучение',
#  'ЕФ АО "СМП БАНК" г. ЕКАТЕРИНБУРГ',
#  'Центр "Биоинженерия" Российской Академии Наук',
#  'софтвер',
#  'ФИЛИАЛ N 7806 БАНКА ВТБ (ПАО) г. САНКТ-ПЕТЕРБУРГ',
#  '044525182',
#  'взвинчивание',
#  '044030715',
#  'РКЦ ХАНТЫ-МАНСИЙСК г. ХАНТЫ-МАНСИЙСК',
#  'насплетничаться',
#  'улететь',
#  'переснаряжать',
#  'четырёхугольный',
#  'подсмена',
#  'КПП',
#  'чокнутый',
#  'дресвяник',
#  'расстыковаться',
#  'копытка',
#  '30101810845250000245',
#  '046850649',
#  'отработаться',
#  'официозный',
#  'ФИЛИАЛ "МОСКОВСКИЙ" ПАО "СКБ-БАНК" г. МОСКВА',
#  '30101810300000000341',
#  'полнокомплектный',
#  'раскатать',
#  'льноутомление',
#  'шпильман',
#  'асебия',
#  'перебинтованный',
#  '044525553',
#  'АО УКБ "БЕЛГОРОДСОЦБАНК" г. БЕЛГОРОД',
#  'ООО РНКО "РИБ" г. МОСКВА',
#  '042265825',
#  '30101810745250000413',
#  'научно-теоретический',
#  'неравный',
#  'плодоовощевод']

# %%
a = np.array([[1,4,1],
              [3,1,5]])
# a = np.sort(a, axis=0,order=[1])                # sort along the last axis

a = a[a[:,1].argsort()][0]
a = np.expand_dims(a, axis=0)
print(a)
# np.sort(a, axis=None)     # sort the flattened array
# array([1, 1, 3, 4])
# np.sort(a, axis=0)        # sort along the first axis
# array([[1, 1],
#        [3, 4]])
# Out:
# [[3 1 5]]
